# %%
# !pip install pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
#1 create dataframe
df = pd.DataFrame([11,22,33], columns=['col_Name'])
print(df)
# Out:
#    col_Name
# 0        11
# 1        22
# 2        33

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = {
    'Name':['Bishwas','Vishika','lalita','Rohit'],
    'Age':[16,11,22,33],
    'salary':[30000,300000,400000,50000]

}

# %%
df= pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  salary
# 0  Bishwas   16   30000
# 1  Vishika   11  300000
# 2   lalita   22  400000
# 3    Rohit   33   50000

# %%
#2.Basic DataFrame understanding

# %%
df.head(3)  #to print top rows
# Out:
#       Name  Age  salary
# 0  Bishwas   16   30000
# 1  Vishika   11  300000
# 2   lalita   22  400000

# %%
df.tail(2)
# Out:
#      Name  Age  salary
# 2  lalita   22  400000
# 3   Rohit   33   50000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'salary'], dtype='object')

# %%
#rename columns
df1=df.rename(columns={'salary':'Monthly_salary'})

# %%
df1
# Out:
#       Name  Age  Monthly_salary
# 0  Bishwas   16           30000
# 1  Vishika   11          300000
# 2   lalita   22          400000
# 3    Rohit   33           50000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#              Age         salary
# count   4.000000       4.000000
# mean   20.500000  195000.000000
# std     9.469248  183757.086031
# min    11.000000   30000.000000
# 25%    14.750000   45000.000000
# 50%    19.000000  175000.000000
# 75%    24.750000  325000.000000
# max    33.000000  400000.000000

# %%
#3.save and load data from csv

# %%
df.to_csv('test_data.csv',index='none')

# %%
load_df=pd.read_csv('test_data.csv')
load_df
# Out:
#    Unnamed: 0     Name  Age  salary
# 0           0  Bishwas   16   30000
# 1           1  Vishika   11  300000
# 2           2   lalita   22  400000
# 3           3    Rohit   33   50000

# %%
#4.rows columns selection

# %%
df[['Name']]
# Out:
#       Name
# 0  Bishwas
# 1  Vishika
# 2   lalita
# 3    Rohit

# %%
df[['Name','salary']]
# Out:
#       Name  salary
# 0  Bishwas   30000
# 1  Vishika  300000
# 2   lalita  400000
# 3    Rohit   50000

# %%
df.loc[df.Name=='Bishwas']  #loc = label based index
# Out:
#       Name  Age  salary
# 0  Bishwas   16   30000

# %%
df.loc[(df.Name=='Bishwas') & (df.Age>15)]
# Out:
#       Name  Age  salary
# 0  Bishwas   16   30000

# %%
#iloc - index value based
df.iloc[0]
df.iloc[0:3]  #[start:stop:step]
# Out:
#       Name  Age  salary
# 0  Bishwas   16   30000
# 1  Vishika   11  300000
# 2   lalita   22  400000

# %%
#5.filter dataframe
df
# Out:
#       Name  Age  salary
# 0  Bishwas   16   30000
# 1  Vishika   11  300000
# 2   lalita   22  400000
# 3    Rohit   33   50000

# %%
df['Age']>15
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# Name: Age, dtype: bool

# %%
df[df['Age']>15]
# Out:
#       Name  Age  salary
# 0  Bishwas   16   30000
# 2   lalita   22  400000
# 3    Rohit   33   50000

# %%
df_age_filter=df[df['Age']>15]
df_age_filter
# Out:
#       Name  Age  salary
# 0  Bishwas   16   30000
# 2   lalita   22  400000
# 3    Rohit   33   50000

# %%
df[(df['Age'] >15) & (df['salary'] >=50000)]
# Out:
#      Name  Age  salary
# 2  lalita   22  400000
# 3   Rohit   33   50000

# %%
df.where(df['Age']>15 ,other='not eligible')
# Out:
#            Name           Age        salary
# 0       Bishwas            16         30000
# 1  not eligible  not eligible  not eligible
# 2        lalita            22        400000
# 3         Rohit            33         50000
